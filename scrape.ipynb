# %% [markdown]
# ### Importing essential libraries required for data manipulation, timing control, and system-level operations

# %%
import pandas as pd
import time
import sys
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ### Web Scraping Process
#
# This code scrapes aviation safety data from the ASN Flightsafety website by year and page.
#
# - Custom HTTP headers are set to mimic a browser and avoid being blocked.
# - The script loops through years starting from 1995 up to 2025, fetching all available pages for each year.
# - Data tables from each page are read with pandas and stored in a list.
# - Progress is shown in the console with real-time updates.
# - When no more pages are found for a year, it moves to the next year automatically.
# - Errors are handled to continue scraping without stopping unexpectedly.
# - A 1-second pause between requests helps to be polite to the server.
# - The process stops after scraping all years up to 2025.

# %%
headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/124.0.0.0 Safari/537.36"
    ),
    "Accept-Language": "en-US,en;q=0.9",
    "Referer": "https://asn.flightsafety.org/",
}

year = 1995
page = 1
dfs = []

while True:
    if year <= 2025:
        url = f"https://asn.flightsafety.org/database/year/{year}/{page}"
        try:
            sys.stdout.write(f"\rScraping page - {year}, page {page}...")
            sys.stdout.flush()

            data = pd.read_html(
                url,
                storage_options=headers,
                skiprows=0,
                header=None
            )
            dfs.append(data[0])

            # Overwrite the line to indicate success
            sys.stdout.write(f"\rScraping year - {year}, page {page}... Finished successfully!\n")
            sys.stdout.flush()

            page += 1
            time.sleep(1)
            continue

        except Exception as e:
            if isinstance(e, ValueError):
                print(f"\nFinished scraping data for {year} successfully!")
                print(f"No more data found at {year}. Continuing with year {year + 1}\n")
            else:
                print(f"\nUnexpected error at year {year}, page {page}: {e}")
            year += 1
            page = 1
            continue
    else:
        print("\nScraping completed for all years.")
        break
# Out:
# Scraping year - 1995, page 1... Finished successfully!
# Scraping year - 1995, page 2... Finished successfully!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 35
#      32     sys.stdout.flush()
#      34     page += 1
# ---> 35     time.sleep(1)
#      36     continue
#      38 except Exception as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Data Aggregation and Export
#
# - All collected page DataFrames stored in the list `dfs` are combined into a single DataFrame using `pd.concat`, with the index reset to ensure continuous numbering.
# - The resulting complete dataset is displayed for review.
# - Finally, the dataset is exported to a CSV file named `"asn_dataset"` with UTF-8 encoding, including column headers and excluding the DataFrame index.

# %%
dataset = pd.concat(dfs, ignore_index=True)
dataset
dataset.to_csv("asn_dataset", encoding='utf-8', index=False, header=True)

# %%
req = requests.get("https://asn.flightsafety.org/database/year/1995/1", headers=headers)
soup = BeautifulSoup(req.text)

table = soup.body.find("table", class_="hp")
table_rows = table.find_all("tr")

data = []
for tr in table_rows:
    cols = tr.find_all("td")
    if not cols:
        continue

    
    row = []
    link = None
    
    for i, td in enumerate(cols):
        text = td.get_text(strip=True)

        if i == 0:
            span = td.find("span")
            a_tag = span.find("a")
            if a_tag and "href" in a_tag.attrs:
                link = a_tag["href"]
        row.append(text)

    row.append("https://asn.flightsafety.org" + link if link else None)
    data.append(row)

data
# Out:
# [['2 Jan 1995',
#   'Boeing 737-298C',
#   '9Q-CNI',
#   'Air Zaire',
#   '0',
#   "Kinshasa-N'Djili Airport (FIH)",
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324813'],
#  ['2 Jan 1995',
#   'Cessna 208 Caravan I',
#   'N242SS',
#   'Taquan Air Service',
#   '0',
#   'Craig, AK',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/359440'],
#  ['3 Jan 1995',
#   'de Havilland Canada DHC-6 Twin Otter 310',
#   'P2-IAA',
#   'Islands Nationair',
#   '0',
#   'Bili',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324812'],
#  ['4 Jan 1995',
#   'Fokker 50?',
#   '',
#   'Sudan Airways',
#   '0',
#   'Port Sudan Airport (PZU)',
#   '',
#   'non',
#   '',
#   'https://asn.flightsafety.org/wikibase/324811'],
#  ['5 Jan 1995',
#   'Fokker 50',
#   'LN-BBA',
#   'Braathens SAFE, lsf Norwegian Air Shuttle',
#   '0',
#   'Ålesund-Vigra Airport (AES)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324809'],
#  ['5 Jan 1995',
#   'Lockheed L-1329-25 JetStar II',
#   '1003',
#   'Imperial Iranian Air Force - IIAF',
#   '12',
#   'near Isfahan-Shahid Beheshti Airport (IFN)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324810'],
#  ['6 Jan 1995',
#   'McDonnell Douglas MD-88',
#   'N981DL',
#   'Delta Air Lines',
#   '0',
#   'Monroe, LA',
#   '',
#   'non',
#   '',
#   'https://asn.flightsafety.org/wikibase/359433'],
#  ['8 Jan 1995',
#   'Cessna 208 Caravan I',
#   'VH-MMV',
#   'A. McVinish',
#   '0',
#   'Toogoolawah Airport, QLD',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324808'],
#  ['10 Jan 1995',
#   'Rockwell Sabreliner 60',
#   'N771WW',
#   "Wallace's Bookstore Inc",
#   '0',
#   'Lexington-Blue Grass Airport, KY (LEX)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324805'],
#  ['10 Jan 1995',
#   'Douglas DC-9-14',
#   'HK-3839X',
#   'Intercontinental de Aviación',
#   '51',
#   'near Maria La Baja',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324806'],
#  ['10 Jan 1995',
#   'de Havilland Canada DHC-6 Twin Otter 300',
#   'PK-NUK',
#   'Merpati Nusantara Airlines',
#   '14',
#   'Molo Strait',
#   '',
#   'mis',
#   '',
#   'https://asn.flightsafety.org/wikibase/324807'],
#  ['10 Jan 1995',
#   'McDonnell Douglas DC-9-32',
#   'N922VV',
#   'Valujet Airlines',
#   '0',
#   'Memphis, TN',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/359426'],
#  ['11 Jan 1995',
#   'Cessna S550 Citation S/II',
#   'N287MC',
#   'Maytag Corporation',
#   '0',
#   'Newton Municipal Airport, IA (TNU)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324802'],
#  ['11 Jan 1995',
#   'Learjet 35',
#   'C-GPUN',
#   'Canada Jet\xa0Charters',
#   '5',
#   '15 km NW off Masset Airport, BC (ZMT)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324803'],
#  ['11 Jan 1995',
#   'Cessna 208B Super Cargomaster',
#   'N746FE',
#   'Empire Airlines, opf FedEx',
#   '1',
#   '2 km SSE of Flagstaff-Pulliam Field, AZ (FLG)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324804'],
#  ['12 Jan 1995',
#   'Cessna 208B Super Cargomaster',
#   'N754FE',
#   'West Air, opf Federal Express',
#   '1',
#   'Pleasanton, CA',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324801'],
#  ['14 Jan 1995',
#   'Yakovlev Yak-40',
#   'RA-87565',
#   'CHELAL - Chelyabinskie Avialinii',
#   '0',
#   'Tobolsk Airport (TOX)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324800'],
#  ['15 Jan 1995',
#   'Swearingen SA226-TC Metro II',
#   'N622SP',
#   'City Air Cargo',
#   '1',
#   'near Neuquén, NE',
#   '',
#   'non',
#   '',
#   'https://asn.flightsafety.org/wikibase/324799'],
#  ['16 Jan 1995',
#   'Antonov An-26',
#   '',
#   'Força Aérea Popular de Angola',
#   '6',
#   'North Angola',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324797'],
#  ['16 Jan 1995',
#   'Boeing 737-281',
#   'PK-JHF',
#   'Sempati Air Transport',
#   '0',
#   'Yogyakarta-Adisutjipto Airport (JOG)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324798'],
#  ['17 Jan 1995',
#   'de Havilland Canada DHC-6 Twin Otter 300',
#   '9N-ABI',
#   'Royal Nepal Airlines',
#   '2',
#   'Kathmandu-Tribhuvan Airport (KTM)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324796'],
#  ['18 Jan 1995',
#   'Antonov An-32B',
#   'UR-48074',
#   'Miabi Air Company',
#   '0',
#   "Kinshasa-N'Dolo Airport (NLO)",
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324794'],
#  ['18 Jan 1995',
#   'Cessna 208B Super Cargomaster',
#   'N9461R',
#   'Martinaire',
#   '0',
#   'near Lubbock International Airport, TX (LBB)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324795'],
#  ['20 Jan 1995',
#   'Let L-410UVP',
#   'RA-67120',
#   'Abakan Airlines',
#   '3',
#   'near Krasnoyarsk Airport (KJA)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324792'],
#  ['20 Jan 1995',
#   'Dassault Falcon 20E',
#   'F-GHLN',
#   'Leadair UniJet',
#   '10',
#   'Paris-Le Bourget Airport (LBG)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324793'],
#  ['21 Jan 1995',
#   'Boeing 747-428',
#   'CN-RGA',
#   'Royal Air Maroc - RAM',
#   '0+3',
#   'Montreal (Mirabel) International Airport, Quebec',
#   '',
#   'unk',
#   '',
#   'https://asn.flightsafety.org/wikibase/18539'],
#  ['21 Jan 1995',
#   'Tupolev Tu-154B-2',
#   'UN-85455',
#   'Kazakhstan Airlines',
#   '0',
#   'Karachi International Airport (KHI)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324791'],
#  ['21 Jan 1995',
#   'Airbus A310-324',
#   '9V-STZ',
#   'Singapore Airlines',
#   '0',
#   '27 KM Northeast of Fukue City, Nagasaki Prefecture',
#   '',
#   'non',
#   '',
#   'https://asn.flightsafety.org/wikibase/518159'],
#  ['23 Jan 1995',
#   'Let L-410UVP',
#   'UR-67115',
#   'Air Ukraine',
#   '0',
#   'ca 1,3 km from Provedenia Airport (PVX)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324790'],
#  ['25 Jan 1995',
#   'Britten-Norman BN-2A-27\xa0Islander',
#   'C-GSGK',
#   'Northway Aviation',
#   '0',
#   'Paungassi, MN',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324787'],
#  ['25 Jan 1995',
#   'Yakovlev Yak-40',
#   'RA-87464',
#   'Volga Airlines',
#   '0',
#   'Rostov Airport (ROV)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324788'],
#  ['25 Jan 1995',
#   'Cessna 550\xa0Citation II',
#   'D-CHVB',
#   'Viessmann Werke',
#   '2',
#   'Allendorf',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324789'],
#  ['26 Jan 1995',
#   'Antonov An-26B',
#   'UN-26080',
#   'Guinée Air Service, lsf Kazakhstan Airlines',
#   '0',
#   'Koundara-Sambailo Airport (SBI)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324786'],
#  ['26 Jan 1995',
#   'Dornier 228-202K',
#   'G-BVTY',
#   'City Air Bus',
#   '0',
#   'London-City Airport (LCY/EGLC)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/491696'],
#  ['27 Jan 1995',
#   'Boeing 737-2H4',
#   'N71SW',
#   'Southwest Airlines',
#   '0',
#   'Dallas, TX',
#   '',
#   'non',
#   '',
#   'https://asn.flightsafety.org/wikibase/359388'],
#  ['28 Jan 1995',
#   'Boeing 747-238B',
#   'N706CK',
#   'Kalitta American International Airways',
#   '0',
#   'Detroit-Willow Run Airport, MI (YIP)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324784'],
#  ['28 Jan 1995',
#   'Beechcraft 200 Super King Air',
#   'D2-ECH',
#   'SAL - Sociedade de Aviaçao Ligeira',
#   '2',
#   'near Cafunfo Airport (CFF)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324785'],
#  ['29 Jan 1995',
#   'McDonnell Douglas DC-8-62AF',
#   'N791AL',
#   'Arrow Air',
#   '0',
#   'Manaus-Eduardo Gomes International Airport, AM (MAO)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324783'],
#  ['30 Jan 1995',
#   'ATR 72-202',
#   'B-22717',
#   'TransAsia Airways',
#   '4',
#   '20 km SSE of Taipei-Songshan Airport (TSA)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324782'],
#  ['31 Jan 1995',
#   'Boeing 727-21F',
#   'D2-TJB',
#   'Angola Air Charter',
#   '0',
#   'Huambo Airport (NOV)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324781'],
#  ['xx Jan 1995',
#   'Ilyushin Il-22M15',
#   'UN-75915',
#   'Kazakhstan Government',
#   '0',
#   'Almaty Airport (ALA)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324780'],
#  ['1 Feb 1995',
#   'Antonov An-28',
#   'CCCP-28797',
#   'Chukotavia',
#   '0',
#   'Mys Shmidta Airport',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324779'],
#  ['2 Feb 1995',
#   'Harbin Y-12-II',
#   '9M-TAE',
#   'Berjaya Air',
#   '0',
#   'Kuala Lumpur International Airport (KUL)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324777'],
#  ['2 Feb 1995',
#   'Boeing 737-2A1',
#   'PP-SMV',
#   'VASP - Viação Aérea São Paulo',
#   '0',
#   'São Paulo-Guarulhos International Airport, SP (GRU)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324778'],
#  ['6 Feb 1995',
#   'Antonov An-24B',
#   'RA-46564',
#   'Arkhangelsk Airlines',
#   '0',
#   'Arkhangelsk Airport (ARH)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324776'],
#  ['9 Feb 1995',
#   'Antonov An-2R',
#   'LY-ALE',
#   'Aviapaslauga',
#   '',
#   'Grajewo',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324775'],
#  ['10 Feb 1995',
#   'Ilyushin Il-62M',
#   'RA-86693',
#   'Dalavia',
#   '0',
#   'Khabarovsk-Novy Airport (KHV)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324773'],
#  ['10 Feb 1995',
#   'Antonov An-70',
#   'UR--',
#   'Antonov Design Bureau',
#   '7',
#   'near Gostomel',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324774'],
#  ['14 Feb 1995',
#   'Dornier Do 28D-2 Skyservant',
#   '',
#   'Turkish Army',
#   '3',
#   'Istanbul',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324772'],
#  ['15 Feb 1995',
#   'Cessna 525\xa0CitationJet',
#   'N63HB',
#   'M&M Air',
#   '0',
#   'Wauchula, FL',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324771'],
#  ['16 Feb 1995',
#   'McDonnell Douglas DC-8-63F',
#   'N782AL',
#   'Air Transport International - ATI',
#   '3',
#   'Kansas City International Airport, MO (MCI)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324770'],
#  ['21 Feb 1995',
#   'Beechcraft A100 King Air',
#   'C-GYQT',
#   'Bearskin Airlines',
#   '0',
#   '4,8 km NW of Big Trout Airport, ON (YTL)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324767'],
#  ['21 Feb 1995',
#   'Shin Meiwa US-1A',
#   '9080',
#   'Japan Maritime Self Defence Force - JMSDF',
#   '10',
#   'off Oki Island',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324768'],
#  ['21 Feb 1995',
#   'IAI 1124 Westwind',
#   'N66JE',
#   'Professional Jet Management',
#   '0',
#   'Denver-Stapleton International Airport, CO (DEN)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324769'],
#  ['26 Feb 1995',
#   'Embraer EMB-120RT Brasilia',
#   'PT-OQI',
#   'Nordeste Linhas Aéreas Regionais',
#   '0',
#   'Recife, PE',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/317296'],
#  ['1 Mar 1995',
#   'Mitsubishi Mu-300 Diamond IA',
#   'C-GLIG',
#   'Lignum Ltd.',
#   '0',
#   'Jasper-Hinton Airport, AB (YJP)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324766'],
#  ['2 Mar 1995',
#   'Cessna 208B Super Cargomaster',
#   'N9448B',
#   'Martinaire',
#   '0',
#   'Ardmore, OK',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/359288'],
#  ['3 Mar 1995',
#   'IAI 1124A Westwind II',
#   'N311BR',
#   'Kennecott Corp',
#   '0',
#   'Gillette-Campbell County Airport, WY (GCC)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324764'],
#  ['3 Mar 1995',
#   'Cessna 208B Grand Caravan',
#   'N227DM',
#   'DMC Flying Service',
#   '2',
#   '1,2 km SSE of Gainesville-Lee Gilmer Memorial Airport, GA (GVL)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324765'],
#  ['4 Mar 1995',
#   'Harbin Y-12-II',
#   'PNP-224',
#   'Policía Nacional del Perú',
#   '0',
#   'Bom Jesus, AC',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324763'],
#  ['5 Mar 1995',
#   'Beechcraft 1900C',
#   'N130UE',
#   'United Express, opb Great Lakes Airlines',
#   '0',
#   'Minneapolis-St. Paul International Airport, MN (MSP)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324762'],
#  ['12 Mar 1995',
#   'Lockheed L-1011 TriStar 500',
#   'N724DA',
#   'Delta Air Lines',
#   '0',
#   'San Juan-Luis Muñoz Marín International Airport (SJU)',
#   '',
#   'min',
#   '',
#   'https://asn.flightsafety.org/wikibase/324759'],
#  ['12 Mar 1995',
#   'Shorts 360-200',
#   'N376MQ',
#   'American Eagle, opb Executive Airlines',
#   '0',
#   'San Juan-Luis Muñoz Marín International Airport (SJU)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324760'],
#  ['12 Mar 1995',
#   'Douglas C-47B-DK (DC-3)',
#   'C-FDTT',
#   'Transfair',
#   '0',
#   'Lac Manitou, QC',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324761'],
#  ['13 Mar 1995',
#   'Lockheed L-188A Electra',
#   '9Q-CDG',
#   'Blue Airlines',
#   '0',
#   "Kinshasa-N'Djili Airport (FIH)",
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324758'],
#  ['14 Mar 1995',
#   'Antonov An-12B',
#   'RA-11337',
#   'Penza Air Enterprise',
#   '0',
#   '6 km from Baku',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324757'],
#  ['16 Mar 1995',
#   'de Havilland Canada DHC-6 Twin Otter 200',
#   'N37ST',
#   'Great Barrier Airlines (New Zealand)',
#   '0',
#   '325 km off Oahu Island, HI, USA',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324755'],
#  ['16 Mar 1995',
#   'Antonov An-26B',
#   'RA-26084',
#   'Central Region Airlines',
#   '9',
#   '8 km S of Ossora Airport',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324756'],
#  ['16 Mar 1995',
#   'Boeing 727-247 Adv.',
#   'N295WA',
#   'Delta Air Lines',
#   '0',
#   'Alma, GA',
#   '',
#   'non',
#   '',
#   'https://asn.flightsafety.org/wikibase/359237'],
#  ['17 Mar 1995',
#   'Boeing 737-260 Advanced',
#   'ET-AJB',
#   'Ethiopian Airlines',
#   '0',
#   'El Obeid Airport (EBD)',
#   '',
#   'non',
#   '',
#   'https://asn.flightsafety.org/wikibase/324753'],
#  ['17 Mar 1995',
#   'McDonnell Douglas DC-9-15',
#   'HK-3564X',
#   'Intercontinental de Aviación',
#   '0',
#   'Barranquilla-Ernesto Cortissoz International Airport (BAQ)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324754'],
#  ['18 Mar 1995',
#   'Convair CV-440',
#   'N137CA',
#   'Gulf & Caribbean Cargo, lsf Winemiller Aviation',
#   '0',
#   'Cap Haitien Airport (CAP)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324752'],
#  ['20 Mar 1995',
#   'Cessna 208B Grand Caravan',
#   '9M-PMN',
#   'Transmile Air Service',
#   '0',
#   'Tawau Airport (TWU)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324751'],
#  ['22 Mar 1995',
#   'Cessna 208B Super Cargomaster',
#   'N9417B',
#   'Union Flights',
#   '1',
#   'Reno, NV',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324750'],
#  ['23 Mar 1995',
#   'Douglas DC-3C',
#   'C-GCXD',
#   'Aviation Boreal',
#   '0',
#   'Lac Bondesir, QC',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324749'],
#  ['25 Mar 1995',
#   'Lockheed P-3C Orion',
#   '158217',
#   'United States Navy',
#   '0',
#   '8 km off Masirah Airport (MSH)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324747'],
#  ['25 Mar 1995',
#   'Antonov An-12',
#   'RA-13340',
#   'Amuraviatrans',
#   '0',
#   'Bunia Airport (BUX)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324748'],
#  ['25 Mar 1995',
#   'Beechcraft 1900C',
#   'N34010',
#   'GP Express Airlines',
#   '0',
#   'Covington, KY',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/359199'],
#  ['28 Mar 1995',
#   'Fokker F-28 Fellowship 4000',
#   'PK-GQB',
#   'Merpati Nusantara Airlines',
#   '0',
#   'Bandung-Husein Sastranegara Airport (BDO)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324746'],
#  ['31 Mar 1995',
#   'Airbus A310-324',
#   'YR-LCC',
#   'Tarom',
#   '60',
#   '3 km N of Bucharest-Otopeni International Airport (OTP)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324745'],
#  ['1 Apr 1995',
#   'Antonov An-2',
#   '',
#   'African Air Charter',
#   '1',
#   'near Kenema Airport (KEN)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324744'],
#  ['2 Apr 1995',
#   'McDonnell Douglas MD-11',
#   'N1768D',
#   'American Airlines',
#   '0',
#   'New York-John F. Kennedy International Airport, NY (JFK/KJFK)',
#   '',
#   'non',
#   '',
#   'https://asn.flightsafety.org/wikibase/190676'],
#  ['4 Apr 1995',
#   'Antonov An-26B',
#   'RA-26049',
#   'Central Region Airlines',
#   '0',
#   'Palana Airport',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324742'],
#  ['4 Apr 1995',
#   'Harbin Y-12-II',
#   'OB-1498/333',
#   'Transportes Aéreos Nacionales de la Selva - TANS',
#   '3',
#   'near Iquitos Airport (IQT)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324743'],
#  ['6 Apr 1995',
#   'Transall C-160NG',
#   'F-222/64-GV',
#   "L'Armée de L'Air",
#   '0',
#   'near Occhiatana',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324741'],
#  ['7 Apr 1995',
#   'Hawker Siddeley HS-125-400',
#   'N41953',
#   'Jetcraft Corp.',
#   '0',
#   'Santo Domingo-Herrera Airport (HEX)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324740'],
#  ['8 Apr 1995',
#   'Boeing 747-2U3B',
#   'PK-GSE',
#   'Garuda Indonesia Airways',
#   '0',
#   'near London-Gatwick Airport (LGW)',
#   '',
#   'min',
#   '',
#   'https://asn.flightsafety.org/wikibase/324738'],
#  ['8 Apr 1995',
#   'Convair CV-580',
#   'HK-3675',
#   'SEC Colombia',
#   '0',
#   'Espinal-Aguablanca Agricultural Airstrip',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324739'],
#  ['11 Apr 1995',
#   'Cessna 208A Caravan I',
#   'PT-OGO',
#   'Transportes Aéreos Meridionais - TAM',
#   '0',
#   'Luziânia Airport, GO',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324737'],
#  ['11 Apr 1995',
#   'Boeing 757-223',
#   'N683A',
#   'American Airlines',
#   '0',
#   'San Antonio, TX',
#   '',
#   'non',
#   '',
#   'https://asn.flightsafety.org/wikibase/359142'],
#  ['12 Apr 1995',
#   'Beechcraft 200 Super King Air',
#   'P2-IAH',
#   'Islands Nationair',
#   '0',
#   'Lae-Nadzab Airport (LAE)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324736'],
#  ['13 Apr 1995',
#   'Boeing 737-4Y0',
#   'EI-CEU',
#   'MarkAir',
#   '0',
#   'Denver International Airport, CO (DEN)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324732'],
#  ['13 Apr 1995',
#   'Aero Modifications AMI C-47TP (DC-3T)',
#   'ZS-LYW',
#   'Wonderair',
#   '2',
#   'Kikwangala',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324733'],
#  ['13 Apr 1995',
#   'Yakovlev Yak-40K',
#   'UN-88181',
#   'Kazakhstan Airlines',
#   '0',
#   'Dzhambul Airport (DMB)',
#   '',
#   'sub',
#   '',
#   'https://asn.flightsafety.org/wikibase/324734'],
#  ['13 Apr 1995',
#   'Antonov An-2R',
#   'RA-40845',
#   'Cheboksary Aviation Enterprise',
#   '0',
#   'Tyugalbuga, Novaya Malykla district',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324735'],
#  ['15 Apr 1995',
#   'Tupolev Tu-134A-3',
#   'OB-1553',
#   'Imperial Air',
#   '0',
#   'Lima-J Chavez International Airport (LIM)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324731'],
#  ['17 Apr 1995',
#   'Douglas C-54G-5-DO (DC-4)',
#   'N898AL',
#   'Brooks Air Fuel',
#   '0',
#   'Kivalina Airport, AK (KVL)',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324729'],
#  ['17 Apr 1995',
#   'Learjet C-21A (Learjet 35A)',
#   '84-0136',
#   'United States Air Force - USAF',
#   '8',
#   '6,5 km E of Alexander City Airport, AL',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324730'],
#  ['19 Apr 1995',
#   'Antonov An-2R',
#   'SP-WNY',
#   'Zakladu Uslug Agrolotniczych - ZUA',
#   '',
#   'Qom',
#   '',
#   'w/o',
#   '',
#   'https://asn.flightsafety.org/wikibase/324728'],
#  ['19 Apr 1995',
#   'McDonnell Douglas MD-82',
#   'N83872',
#   'Continental Airlines',
#   '0',
#   'Utopia, TX',
#   '',
#   'non',
#   '',
#   'https://asn.flightsafety.org/wikibase/359104']]
