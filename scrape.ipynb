# %% [markdown]
# ### Importing essential libraries required for data manipulation, timing control, and system-level operations

# %%
import pandas as pd
import time
import sys

# %% [markdown]
# ### Web Scraping Process
#
# This code scrapes aviation safety data from the ASN Flightsafety website by year and page.
#
# - Custom HTTP headers are set to mimic a browser and avoid being blocked.
# - The script loops through years starting from 1995 up to 2025, fetching all available pages for each year.
# - Data tables from each page are read with pandas and stored in a list.
# - Progress is shown in the console with real-time updates.
# - When no more pages are found for a year, it moves to the next year automatically.
# - Errors are handled to continue scraping without stopping unexpectedly.
# - A 1-second pause between requests helps to be polite to the server.
# - The process stops after scraping all years up to 2025.

# %%
headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/124.0.0.0 Safari/537.36"
    ),
    "Accept-Language": "en-US,en;q=0.9",
    "Referer": "https://asn.flightsafety.org/",
}

year = 1995
page = 1
dfs = []

while True:
    if year <= 2025:
        url = f"https://asn.flightsafety.org/database/year/{year}/{page}"
        try:
            sys.stdout.write(f"\rScraping page - {year}, page {page}...")
            sys.stdout.flush()

            data = pd.read_html(
                url,
                storage_options=headers,
                skiprows=0,
                header=None
            )
            dfs.append(data[0])

            # Overwrite the line to indicate success
            sys.stdout.write(f"\rScraping year - {year}, page {page}... Finished successfully!\n")
            sys.stdout.flush()

            page += 1
            time.sleep(1)
            continue

        except Exception as e:
            if isinstance(e, ValueError):
                print(f"\nFinished scraping data for {year} successfully!")
                print(f"No more data found at {year}. Continuing with year {year + 1}\n")
            else:
                print(f"\nUnexpected error at year {year}, page {page}: {e}")
            year += 1
            page = 1
            continue
    else:
        print("\nScraping completed for all years.")
        break
# Out:
# Scraping page - 1995, page 1... Finished successfully!
# Scraping page - 1995, page 2... Finished successfully!
# Scraping page - 1995, page 3... Finished successfully!
# Scraping page - 1995, page 4... Finished successfully!
# Scraping page - 1995, page 5...
# Finished scraping data for 1995 successfully!
# No more data found at 1995. Continuing with year 1996
#
# Scraping page - 1996, page 1... Finished successfully!
# Scraping page - 1996, page 2... Finished successfully!
# Scraping page - 1996, page 3... Finished successfully!
# Scraping page - 1996, page 4... Finished successfully!
# Scraping page - 1996, page 5...
# Finished scraping data for 1996 successfully!
# No more data found at 1996. Continuing with year 1997
#
# Scraping page - 1997, page 1... Finished successfully!
# Scraping page - 1997, page 2... Finished successfully!
# Scraping page - 1997, page 3... Finished successfully!
# Scraping page - 1997, page 4... Finished successfully!
# Scraping page - 1997, page 5...
# Finished scraping data for 1997 successfully!
# No more data found at 1997. Continuing with year 1998
#
# Scraping page - 1998, page 1... Finished successfully!
# Scraping page - 1998, page 2... Finished successfully!
# Scraping page - 1998, page 3... Finished successfully!
# Scraping page - 1998, page 4... Finished successfully!
# Scraping page - 1998, page 5...
# Finished scraping data for 1998 successfully!
# No more data found at 1998. Continuing with year 1999
#
# Scraping page - 1999, page 1... Finished successfully!
# Scraping page - 1999, page 2... Finished successfully!
# Scraping page - 1999, page 3... Finished successfully!
# Scraping page - 1999, page 4... Finished successfully!
# Scraping page - 1999, page 5...
# Finished scraping data for 1999 successfully!
# No more data found at 1999. Continuing with year 2000
#
# Scraping page - 2000, page 1... Finished successfully!
# Scraping page - 2000, page 2... Finished successfully!
# Scraping page - 2000, page 3... Finished successfully!
# Scraping page - 2000, page 4... Finished successfully!
# Scraping page - 2000, page 5...
# Finished scraping data for 2000 successfully!
# No more data found at 2000. Continuing with year 2001
#
# Scraping page - 2001, page 1... Finished successfully!
# Scraping page - 2001, page 2... Finished successfully!
# Scraping page - 2001, page 3... Finished successfully!
# Scraping page - 2001, page 4... Finished successfully!
# Scraping page - 2001, page 5...
# Finished scraping data for 2001 successfully!
# No more data found at 2001. Continuing with year 2002
#
# Scraping page - 2002, page 1... Finished successfully!
# Scraping page - 2002, page 2... Finished successfully!
# Scraping page - 2002, page 3... Finished successfully!
# Scraping page - 2002, page 4...
# Finished scraping data for 2002 successfully!
# No more data found at 2002. Continuing with year 2003
#
# Scraping page - 2003, page 1... Finished successfully!
# Scraping page - 2003, page 2... Finished successfully!
# Scraping page - 2003, page 3... Finished successfully!
# Scraping page - 2003, page 4...
# Finished scraping data for 2003 successfully!
# No more data found at 2003. Continuing with year 2004
#
# Scraping page - 2004, page 1... Finished successfully!
# Scraping page - 2004, page 2... Finished successfully!
# Scraping page - 2004, page 3... Finished successfully!
# Scraping page - 2004, page 4...
# Finished scraping data for 2004 successfully!
# No more data found at 2004. Continuing with year 2005
#
# Scraping page - 2005, page 1... Finished successfully!
# Scraping page - 2005, page 2... Finished successfully!
# Scraping page - 2005, page 3... Finished successfully!
# Scraping page - 2005, page 4...
# Finished scraping data for 2005 successfully!
# No more data found at 2005. Continuing with year 2006
#
# Scraping page - 2006, page 1... Finished successfully!
# Scraping page - 2006, page 2... Finished successfully!
# Scraping page - 2006, page 3... Finished successfully!
# Scraping page - 2006, page 4... Finished successfully!
# Scraping page - 2006, page 5...
# Finished scraping data for 2006 successfully!
# No more data found at 2006. Continuing with year 2007
#
# Scraping page - 2007, page 1... Finished successfully!
# Scraping page - 2007, page 2... Finished successfully!
# Scraping page - 2007, page 3... Finished successfully!
# Scraping page - 2007, page 4...
# Finished scraping data for 2007 successfully!
# No more data found at 2007. Continuing with year 2008
#
# Scraping page - 2008, page 1... Finished successfully!
# Scraping page - 2008, page 2... Finished successfully!
# Scraping page - 2008, page 3... Finished successfully!
# Scraping page - 2008, page 4...
# Finished scraping data for 2008 successfully!
# No more data found at 2008. Continuing with year 2009
#
# Scraping page - 2009, page 1... Finished successfully!
# Scraping page - 2009, page 2... Finished successfully!
# Scraping page - 2009, page 3... Finished successfully!
# Scraping page - 2009, page 4...
# Finished scraping data for 2009 successfully!
# No more data found at 2009. Continuing with year 2010
#
# Scraping page - 2010, page 1... Finished successfully!
# Scraping page - 2010, page 2... Finished successfully!
# Scraping page - 2010, page 3... Finished successfully!
# Scraping page - 2010, page 4...
# Finished scraping data for 2010 successfully!
# No more data found at 2010. Continuing with year 2011
#
# Scraping page - 2011, page 1... Finished successfully!
# Scraping page - 2011, page 2... Finished successfully!
# Scraping page - 2011, page 3... Finished successfully!
# Scraping page - 2011, page 4...
# Finished scraping data for 2011 successfully!
# No more data found at 2011. Continuing with year 2012
#
# Scraping page - 2012, page 1... Finished successfully!
# Scraping page - 2012, page 2... Finished successfully!
# Scraping page - 2012, page 3... Finished successfully!
# Scraping page - 2012, page 4...
# Finished scraping data for 2012 successfully!
# No more data found at 2012. Continuing with year 2013
#
# Scraping page - 2013, page 1... Finished successfully!
# Scraping page - 2013, page 2... Finished successfully!
# Scraping page - 2013, page 3... Finished successfully!
# Scraping page - 2013, page 4...
# Finished scraping data for 2013 successfully!
# No more data found at 2013. Continuing with year 2014
#
# Scraping page - 2014, page 1... Finished successfully!
# Scraping page - 2014, page 2... Finished successfully!
# Scraping page - 2014, page 3... Finished successfully!
# Scraping page - 2014, page 4...
# Finished scraping data for 2014 successfully!
# No more data found at 2014. Continuing with year 2015
#
# Scraping page - 2015, page 1... Finished successfully!
# Scraping page - 2015, page 2... Finished successfully!
# Scraping page - 2015, page 3... Finished successfully!
# Scraping page - 2015, page 4...
# Finished scraping data for 2015 successfully!
# No more data found at 2015. Continuing with year 2016
#
# Scraping page - 2016, page 1... Finished successfully!
# Scraping page - 2016, page 2... Finished successfully!
# Scraping page - 2016, page 3... Finished successfully!
# Scraping page - 2016, page 4...
# Finished scraping data for 2016 successfully!
# No more data found at 2016. Continuing with year 2017
#
# Scraping page - 2017, page 1... Finished successfully!
# Scraping page - 2017, page 2... Finished successfully!
# Scraping page - 2017, page 3... Finished successfully!
# Scraping page - 2017, page 4...
# Finished scraping data for 2017 successfully!
# No more data found at 2017. Continuing with year 2018
#
# Scraping page - 2018, page 1... Finished successfully!
# Scraping page - 2018, page 2... Finished successfully!
# Scraping page - 2018, page 3... Finished successfully!
# Scraping page - 2018, page 4...
# Finished scraping data for 2018 successfully!
# No more data found at 2018. Continuing with year 2019
#
# Scraping page - 2019, page 1... Finished successfully!
# Scraping page - 2019, page 2... Finished successfully!
# Scraping page - 2019, page 3... Finished successfully!
# Scraping page - 2019, page 4...
# Finished scraping data for 2019 successfully!
# No more data found at 2019. Continuing with year 2020
#
# Scraping page - 2020, page 1... Finished successfully!
# Scraping page - 2020, page 2... Finished successfully!
# Scraping page - 2020, page 3... Finished successfully!
# Scraping page - 2020, page 4...
# Finished scraping data for 2020 successfully!
# No more data found at 2020. Continuing with year 2021
#
# Scraping page - 2021, page 1... Finished successfully!
# Scraping page - 2021, page 2... Finished successfully!
# Scraping page - 2021, page 3... Finished successfully!
# Scraping page - 2021, page 4...
# Finished scraping data for 2021 successfully!
# No more data found at 2021. Continuing with year 2022
#
# Scraping page - 2022, page 1... Finished successfully!
# Scraping page - 2022, page 2... Finished successfully!
# Scraping page - 2022, page 3... Finished successfully!
# Scraping page - 2022, page 4...
# Finished scraping data for 2022 successfully!
# No more data found at 2022. Continuing with year 2023
#
# Scraping page - 2023, page 1... Finished successfully!
# Scraping page - 2023, page 2... Finished successfully!
# Scraping page - 2023, page 3... Finished successfully!
# Scraping page - 2023, page 4...
# Finished scraping data for 2023 successfully!
# No more data found at 2023. Continuing with year 2024
#
# Scraping page - 2024, page 1... Finished successfully!
# Scraping page - 2024, page 2... Finished successfully!
# Scraping page - 2024, page 3... Finished successfully!
# Scraping page - 2024, page 4...
# Finished scraping data for 2024 successfully!
# No more data found at 2024. Continuing with year 2025
#
# Scraping page - 2025, page 1... Finished successfully!
# Scraping page - 2025, page 2...
# Finished scraping data for 2025 successfully!
# No more data found at 2025. Continuing with year 2026
#
#
# Scraping completed for all years.

# %% [markdown]
# ### Data Aggregation and Export
#
# - All collected page DataFrames stored in the list `dfs` are combined into a single DataFrame using `pd.concat`, with the index reset to ensure continuous numbering.
# - The resulting complete dataset is displayed for review.
# - Finally, the dataset is exported to a CSV file named `"asn_dataset"` with UTF-8 encoding, including column headers and excluding the DataFrame index.

# %%
dataset = pd.concat(dfs, ignore_index=True)
dataset
dataset.to_csv("asn_dataset", encoding='utf-8', index=False, header=True)
